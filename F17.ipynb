# %% [markdown]
# File I/O

# %%
 f=open('F17file.txt','r')
 #data=f.read()
 data=f.read(6)
 print(data)
 f.close()
# Out:
# Rocket

# %%
 f=open('F17file.txt','r')
 data=f.readline()
 print(data)
 data=f.readline()
 print(data)
 f.close()
# Out:
# Rocket Raccoon is a genetically engineered,
#
#  wisecracking raccoon from Marvel Comics,

# %%
 f=open('F17file2.txt','w')
 f.write("Groot is a gentle, tree-like alien from the Guardians of the Galaxy, known for his limited vocabulary — just the phrase, I am Groot — and his loyal, big-hearted nature.")
 f.close()

# %%
 f=open('F17file2.txt','a')
 f.write(" Rocket")
 f.close()

# %%
with open('F17file.txt','r') as f:
      a=f.read()
print(a)
# Out:
# Rocket Raccoon is a genetically engineered,
#  wisecracking raccoon from Marvel Comics,
#   known for his sharp tongue, weapons expertise, and fierce loyalty hidden beneath a rough exterior.

# %%
with open('F17file.txt','w') as f:
      a=f.write("Thor is the Asgardian God of Thunder, a powerful warrior wielding his enchanted hammer Mjolnir (and later the axe Stormbreaker), whose journey takes him from a brash, arrogant prince to a humble, wise protector of both Asgard and Earth.")
print(a)
# Out:
# 236
