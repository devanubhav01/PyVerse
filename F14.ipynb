# %%
a=97
if(a>4):
    print("The value of a is greater than 4")
elif(a>8):
    print("The value of a is greater than 8")
else:
    print("The vaalue is not greater than 4 or 8")
# Out:
# The value of a is greater than 4

# %%
a=97
if(a>4):
    print("The value of a is greater than 4")
if(a>8):
    print("The value of a is greater than 8")
if(a>12):
    print("The value of a is greater than 12")
else:
    print("The vaalue is not greater than 4 or 8")
# Out:
# The value of a is greater than 4
# The value of a is greater than 8
# The value of a is greater than 12

# %%
age=int(input("Enter your age"))
if age>=18:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
age=int(input("Enter your age"))
if age<=18:
    print("Yes")
else:
    print("No")
