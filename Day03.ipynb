# %% [markdown]
# LISTS AND TUPLES

# %%
list1=[8,2.3,[-4.5],["apple","banana"]]
print(list1)
# Out:
# [8, 2.3, [-4.5], ['apple', 'banana']]

# %%
tuple1=(("parrot","sparrow"),("cat","dog"))
print(tuple1)
# Out:
# (('parrot', 'sparrow'), ('cat', 'dog'))

# %%
a=[1,2,3,4,5,6,7]
a[0]=98
print(a)
#print(a[0])
# Out:
# [98, 2, 3, 4, 5, 6, 7]

# %%
a=[45,"groot",9.5,True]
print(a)
# Out:
# [45, 'groot', 9.5, True]

# %%
friends=["tom","groot","rocket","Thanos","trump",81]
print(friends[0:4])
# Out:
# ['tom', 'groot', 'rocket', 'Thanos']

# %%
L1=[1,8,7,2,21,15 ]
print(L1)
L1.sort()
print(L1)
L1.reverse()
print(L1)
L1.append(50)
print(L1)
L1.insert(1,91)
P
# Out:
# [1, 8, 7, 2, 21, 15]
# [1, 2, 7, 8, 15, 21]
# [21, 15, 8, 7, 2, 1]
# [21, 15, 8, 7, 2, 1, 50]
