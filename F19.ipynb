# %%
import numpy as np
myarr=np.array([[3,6,32,7]],np.int64)
myarr
# Out:
# array([[ 3,  6, 32,  7]])

# %%
myarr[0,1]
# Out:
# np.int64(6)

# %%
myarr.shape
# Out:
# (1, 4)

# %%
myarr.dtype
# Out:
# dtype('int64')

# %%
myarr[0,1]
# Out:
# np.int64(6)

# %%
myarr[0,1]=50
myarr
# Out:
# array([[ 3, 50, 32,  7]])

# %%
listarray=np.array([[1,2,3],[5,7,8],[2,4,9]])
listarray
# Out:
# array([[1, 2, 3],
#        [5, 7, 8],
#        [2, 4, 9]])
