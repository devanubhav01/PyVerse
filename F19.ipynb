# %%
import numpy as np
myarr=np.array([[3,6,32,7]],np.int64)
myarr
# Out:
# array([[ 3,  6, 32,  7]])

# %%
myarr[0,1]
# Out:
# np.int64(6)

# %%
myarr.shape
# Out:
# (1, 4)

# %%
myarr.dtype
# Out:
# dtype('int64')
