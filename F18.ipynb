# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

print(arr)
print(arr[0])
print(arr[2])
print(arr + 10)
print(arr * 2)
# Out:
# [10 20 30 40 50]
# 10
# 30
# [20 30 40 50 60]
# [ 20  40  60  80 100]
