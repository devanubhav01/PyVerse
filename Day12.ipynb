# %%
import csv
data=[
    ["name","age","city"],
    ["Alice",30,"New York"],
    ["Trump",25,"London"],
    ["charlie",35,"Chicago"],
]
with open("data.csv","w",newline="") as f:
    writer=csv.writer(f)
    writer.writerows(data)

# %%
import pandas as pd
df=pd.read_csv("data.csv")
print(df)
# Out:
#       name  age      city
# 0    Alice   30  New York
# 1    Trump   25    London
# 2  charlie   35   Chicago

# %%
import pandas as pd
import numpy as np
for col in df.columns:
    print(col)
# Out:
# name
# age
# city

# %%
print(df.types)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(df.types)
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'types'
