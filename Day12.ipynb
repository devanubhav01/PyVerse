# %%
import csv
data=[
    ["name","age","city"],
    ["Alice",30,"New York"],
    ["Trump",25,"London"],
    ["charlie",35,"Chicago"],
]
with open("data.csv","w",newline="") as f:
    writer=csv.writer(f)
    writer.writerows(data)

# %%
import pandas as pd
df=pd.read_csv("data.csv")
print(df)
# Out:
#       name  age      city
# 0    Alice   30  New York
# 1    Trump   25    London
# 2  charlie   35   Chicago

# %%
import pandas as pd
import numpy as np
for col in df.columns:
    print(col)
# Out:
# name
# age
# city

# %%
print(df.dtypes)
# Out:
# name      str
# age     int64
# city      str
# dtype: object

# %%
numerical_features=df.select_dtypes(include=['int64'].columns)
print("Numerical Features")
print(numerical_features)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 numerical_features=df.select_dtypes(include=['int64'].columns)
#       2 print("Numerical Features")
#       3 print(numerical_features)
#
# AttributeError: 'list' object has no attribute 'columns'
