# %% [markdown]
# Practice Set

# %%
a=input("Enter first number: ")
b=input("Enter second number: ")
a=int(a)
b=int(b)
print("sum: ",a+b)
# Out:
# sum:  9

# %%
a=input("Enter number: ")
a=int(a)
b=a%2
print("remainder: ",b)
# Out:
# remainder:  1

# %%
a=input("enter number: ")
a=int(a)
b=a*a
print("square: ",b)
# Out:
# square:  25

# %%
a=input("Enter name: ")
print("Good Afternoon ",a)
# Out:
# Good Afternoon  groot

# %%
letter='''Dear <|NAME|>,
You are selected!

Date: <|DATE|>
'''

name=input("Enter name:")
date=input("Enter date:")

letter=letter.replace("<|NAME|>",name)
letter=letter.replace("<|DATE|>",date)
print(letter)
# Out:
# Dear Groot,
# You are selected!
#
# Date: 28-08-2026

# %%
a="This is a string with double  spaces"
#b=a.find("  ")
c=a.replace("  "," ")
print(c)
# Out:
# This is a string with double spaces

# %%
f1=input("Enter Fruit name:")
f2=input("Enter Fruit name:")
f3=input("Enter Fruit name:")
f4=input("Enter Fruit name:")
L=[f1,f2,f3,f4]
print(L)
# Out:
# ['Apple', 'Mango', 'Orange', 'Guava']

# %%
a=int(input("students marks "))
b=int(input("students marks "))
c=int(input("students marks "))
d=int(input("students marks "))

L=[a,b,c,d]
L.sort()
print(L)
# Out:
# [42, 59, 84, 92]

# %%
a=[2,4,5,6,7,8]

print(a[0]+a[1]+a[2]+a[3]+a[4]+a[5])
print(sum(a))
# Out:
# 32
# 32

# %%
myDict={
    "russia":"Moscow","china":"Beijing","japan":"Tokyo","France":"Paris","India":"New Delhi"
}
a=input("Enter country name:")
print("capital:",myDict.get(a))
# Out:
# capital: New Delhi

# %%
num1=int(input("Enter number 1:")) 
num2=int(input("Enter number 2:")) 
num3=int(input("Enter number 3:")) 
num4=int(input("Enter number 4:")) 
num5=int(input("Enter number 5:")) 
a={num1,num2,num3,num4,num5}
print(a)
# Out:
# {1, 2, 4}

# %%
a={18,"18"}
print(a)
# Out:
# {'18', 18}

# %%
a=set()
a.add(20)
a.add(20.0)
a.add("20")
print(a)
print(len(a))
# Out:
# {'20', 20}
# 2

# %%
a={}
print(type(a))
# Out:
# <class 'dict'>

# %%
a={}
b=input("Enter language:")
c=input("Enter language:")
d=input("Enter language:")
e=input("Enter language:")
a['groot']=b
a['rocket']=c
a['thanos']=d
a['loki']=e
print(a)
# Out:
# {'groot': 'java', 'rocket': 'c', 'thanos': 'c++', 'loki': 'c'}

# %%
a={}
b=input("Enter language:")
c=input("Enter language:")
d=input("Enter language:")
e=input("Enter language:")
a['groot']=b
a['rocket']=c
a['groot']=d
a['loki']=e
print(a)
# Out:
# {'groot': 'c++', 'rocket': 'c', 'loki': 'python'}

# %%
a=int(input("Number 1:"))
b=int(input("Number 2:"))
c=int(input("Number 3:"))
d=int(input("Number 4:"))
if(a>b and a>c and a>d):
    print("greatest number is:",a)
elif(b>a and b>c and b>d):
    print("greatest number is:",b)
elif(c>a and c>b and c>d):
    print("greatest number is:",c)
elif(d>a and d>b and d>c):
    print("greatest number is:",d)
else:
    print("None")
# Out:
# greatest number is: 9

# %%
b=int(input("maths %"))
c=int(input("physics %"))
d=int(input("chemistry %"))
a=(b+c+d)/3
if(a>=40 and b>=33 and c>=33 and d>=33):
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
a="make alot of money"
b="buy now"
c="subscribe this"
d="click this"
e=input("write comment:")
if(a in e):
    spam=True
elif(b in e):
    spam=True       
elif(c in e):
    spam=True       
elif(d in e):
    spam=True 
else:
    spam=False
if(spam):
    print("This text is spam")  
else:
    print("This text is not spam")
# Out:
# This text is not spam

# %%
marks=int(input("Enter your marks"))
if marks>=90:
    grade="Ex"
elif marks>=80:
    grade="A"
elif marks>=70:
    grade="B"
elif marks>=60:
    grade="C"
elif marks>=50:
    grade="D"
else:
    grade="F"

print("Your grade is "+grade)
# Out:
# Your grade is A

# %%
a=int(input("enter number:"))
for i in range(1,11):
    print(i*a)
    i+=1
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
num=int(input("Enter the number"))
for i in range(1,11):
    #print(str(num)+"X"+str(i)+"="+str(i*num))
    print(f"{num}X{i}={num*i}")
# Out:
# 7X1=7
# 7X2=14
# 7X3=21
# 7X4=28
# 7X5=35
# 7X6=42
# 7X7=49
# 7X8=56
# 7X9=63
# 7X10=70

# %%
l1=["Tom","Trump","groot","Rocket"]

for name in l1:
    if name.startswith("T"): 
        print("Hello "+name)
# Out:
# Hello Tom
# Hello Trump

# %%
num = int(input("Enter a number: "))

if num < 2:
    print("Not a prime number")
else:
    for i in range(2, num):
        if num % i == 0:
            print("Not a prime number")
            break
    else:
        print("Prime number")
# Out:
# Prime number

# %%
num = int(input("Enter a number: "))
fact=1
for i in range(1,num+1):
    fact=fact*i
print(fact)
# Out:
# 120

# %%
n=4

for i in range(4):
    print("*"*(i+1))
# Out:
# *
# **
# ***
# ****

# %%
 n=3

 for i in range(3):
    print(" "*(n-i-1),end="")
    print("*"*(2*i+1),end="")
    print(" "*(n-i-1))
# Out:
#   *
#  ***
# *****

# %%
num=int(input("Enter the number"))
for i in range(10,0,-1):
    
    print(f"{num}X{i}={num*i}")
# Out:
# 5X10=50
# 5X9=45
# 5X8=40
# 5X7=35
# 5X6=30
# 5X5=25
# 5X4=20
# 5X3=15
# 5X2=10
# 5X1=5

# %%
def maximum(num1,num2,num3):
   if(num1>num2):
      if(num1>num3):
         return num1
   else:
    if(num2>num3):
        return num2
    else:
        return num3
