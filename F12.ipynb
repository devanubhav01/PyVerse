# %%
a=input("Enter first number: ")
b=input("Enter second number: ")
a=int(a)
b=int(b)
print("sum: ",a+b)
# Out:
# sum:  9

# %%
a=input("Enter number: ")
a=int(a)
b=a%2
print("remainder: ",b)
# Out:
# remainder:  1

# %%
a=input("enter number: ")
a=int(a)
b=a*a
print("square: ",b)
