# %%
str4 = "Captain"
str5 = "America"
str6 = str4 + " " + str5
print(str6)
# Out:
# Captain America

# %%
name = "Guzman"
age = 18
statement = "My name is {} and my age is {}."
print(statement.format(name, age))
# Out:
# My name is Guzman and my age is 18.

# %%
quantity = 2
fruit = "Apples"
cost = 120.0
statement = "I want to buy {} dozen {} for {}$"
print(statement.format(fruit, cost, quantity))
# Out:
# I want to buy Apples dozen 120.0 for 2$
