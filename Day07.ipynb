# %%
str4 = "Captain"
str5 = "America"
str6 = str4 + " " + str5
print(str6)
# Out:
# Captain America

# %%
name = "kim"
age = 18
statement = "My name is {} and my age is {}."
print(statement.format(name, age))
# Out:
# My name is kim and my age is 18.

# %%
quantity = 2
fruit = "Apples"
cost = 120.0
statement = "I want to buy {2} dozen {0} for {1}$"
print(statement.format(fruit, cost, quantity))
# Out:
# I want to buy 2 dozen Apples for 120.0$

# %%
str1 = "I love doing \nYoga. "
print(str1)
# Out:
# I love doing
# Yoga.

# %%
str2 = "Hello  \bWorld !!!"
print(str2)
# Out:
# Hello World !!!

# %%
name="groot"
b="groot Rocket"
print(name[0])
print(name[0:3])
print(name[:2])
print(name[1:])
print(name[-5:-2])
print(name[-5:])
print(name[:-1])
print(name[0:5:2])
print(len(name))
print(name.endswith("abc"))
print(name.endswith("t"))
print(name.count("o"))
print(b.count("groot"))
print(b.capitalize())
print(b.capitalize("Rocket"))
# Out:
# g
# gro
# gr
# root
# gro
# groot
# groo
# got
# 5
# False
# True
# 2
# 1
# Groot rocket
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 17
#      13 print(name.endswith("t"))
#      14 print(name.count("o"))
#      15 print(b.count("groot"))
#      16 print(b.capitalize())
# ---> 17 print(b.capitalize("Rocket"))
#      18
#      19
#
# TypeError: str.capitalize() takes no arguments (1 given)
