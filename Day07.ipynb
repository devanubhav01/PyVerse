# %%
str4 = "Captain"
str5 = "America"
str6 = str4 + " " + str5
print(str6)
# Out:
# Captain America

# %%
name = "Guzman"
age = 18
print("My name is" + name + "and my age is" + age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 name = "Guzman"
#       2 age = 18
# ----> 3 print("My name is" + name + "and my age is" + age)
#
# TypeError: can only concatenate str (not "int") to str
