# %% [markdown]
# DICTIONARY & SETS

# %%
myDict={
    "Russia":"Moscow","China":"Beijing","Japan":"Tokyo","France":"Paris","India":"New Delhi","Marks":[1,2,5],"dict2":{'tesla':'sc'}
}
print(myDict)
print(myDict['Russia'])
print(myDict['Marks'])
# Out:
# {'Russia': 'Moscow', 'China': 'Beijing', 'Japan': 'Tokyo', 'France': 'Paris', 'India': 'New Delhi', 'Marks': [1, 2, 5]}
# Moscow
# [1, 2, 5]
