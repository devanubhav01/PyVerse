# %% [markdown]
# DICTIONARY & SETS

# %%
myDict={
    "Russia":"Moscow","China":"Beijing","Japan":"Tokyo","France":"Paris","India":"New Delhi","Marks":[1,2,5],"dict2":{'tesla':'scientist'}
}
print(myDict)
print(myDict['Russia'])
print(myDict['Marks'])
print(myDict['dict2'])
print(myDict['dict2']['tesla'])
# Out:
# {'Russia': 'Moscow', 'China': 'Beijing', 'Japan': 'Tokyo', 'France': 'Paris', 'India': 'New Delhi', 'Marks': [1, 2, 5], 'dict2': {'tesla': 'scientist'}}
# Moscow
# [1, 2, 5]
# {'tesla': 'scientist'}
# scientist
