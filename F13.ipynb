# %% [markdown]
# DICTIONARY & SETS

# %%
myDict={
    "russia":"Moscow","china":"Beijing","japan":"Tokyo","France":"Paris","India":"New Delhi","Marks":[1,2,5],"dict2":{'tesla':'scientist'}
}
myDict['Marks']=[57,47]
print(myDict)
print(myDict['Russia'])
print(myDict['Marks'])
print(myDict['dict2'])
print(myDict['dict2']['tesla'])
# Out:
# {'russia': 'Moscow', 'china': 'Beijing', 'japan': 'Tokyo', 'France': 'Paris', 'India': 'New Delhi', 'Marks': [57, 47], 'dict2': {'tesla': 'scientist'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 6
#       2     "russia":"Moscow","china":"Beijing","japan":"Tokyo","France":"Paris","India":"New Delhi","Marks":[1,2,5],"dict2":{'tesla':'scientist'}
#       3 }
#       4 myDict['Marks']=[57,47]
#       5 print(myDict)
# ----> 6 print(myDict['Russia'])
#       7 print(myDict['Marks'])
#       8 print(myDict['dict2'])
#       9 print(myDict['dict2']['tesla'])
#
# KeyError: 'Russia'
