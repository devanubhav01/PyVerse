# %% [markdown]
# Functions

# %%
m1=[45,78,86,90]
p1=sum(m1)/4

m2=[80,70,60,40]
p2=sum(m2)/4

print(p1,p2)
# Out:
# 74.75 62.5

# %%
m1=[45,78,86,90]
p1=(m1[0]+m1[1]+m1[2]+m1[3])/4
print(p1)
# Out:
# 74.75

# %%
def percent(marks):
    z=(marks[0]+marks[1]+marks[2]+marks[3])/4
    return z

m1=[45,78,86,90]
p1=percent(m1)

m2=[80,70,60,40]
p2=percent(m2)

print(p1,p2)
# Out:
# 74.75 62.5

# %%
def greet(name):
    print("Good Day,"+name)

def mySum(num1,num2):
    return num1+num2
        
greet("groot")
t=mySum(7,42)
print(t)
# Out:
# Good Day,groot
# 49

# %%
def greet(name):
    print("Good Day,"+name)

def mySum(num1,num2):
    return num1+num2
        
greet("groot")
t=mySum(7,42)
print(t)
