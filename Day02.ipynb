# %%
#ml_env (Python 3.11.15) ~/.conda/envs/ml_env/python.exe
print("Hello world",7)
print(5)
print("Trump")
print(20*5)
# Out:
# Hello world 7
# 5
# Trump
# 100

# %%
a=3
b=4
print("the value of 3+4 is",a+b)
# Out:
# the value of 3+4 is 7

# %%
a=34
a+=2
print(a)
# Out:
# 36

# %%
a=(4>7)
print(a)
# Out:
# False
