# %%
sequence1 = range(4, 14, 2)
for i in sequence1:
    print(i)
# Out:
# 4
# 6
# 8
# 10
# 12

# %%
dict1 = {"name": "Kim", "age": 20, "canVote": True}
print(dict1)
# Out:
# {'name': 'Kim', 'age': 20, 'canVote': True}

# %% [markdown]
# Set data

# %%
set1 = {4, -5, 8, 3,8, 2.9}
print(set1)
# Out:
# {2.9, 3, 4, 8, -5}

# %%
num1 = 8.4
num2 = int(num1)
num3 = complex(num1)

print(num2)
print(num3)
# Out:
# 8
# (8.4+0j)
