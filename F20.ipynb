# %% [markdown]
# # PANDAS

# %%
import numpy as np 
import pandas as pd

# %%
dict1={
    "name":['Tom','Groot','Rocket','Thanos'],
    "marks":[92,72,64,89],
    "city":["New York","New Delhi","London","Berlin"]
}

# %%
df=pd.DataFrame(dict1)
df
# Out:
#      name  marks       city
# 0     Tom     92   New York
# 1   Groot     72  New Delhi
# 2  Rocket     64     London
# 3  Thanos     89     Berlin

# %%
df.to_csv('F20file1.csv')

# %%
df.to_csv('F20file2.csv',index=False)

# %%
df.head(2)
# Out:
#     name  marks       city
# 0    Tom     92   New York
# 1  Groot     72  New Delhi

# %%
df.tail(2)
# Out:
#      name  marks    city
# 2  Rocket     64  London
# 3  Thanos     89  Berlin

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   79.250000
# std    13.450527
# min    64.000000
# 25%    70.000000
# 50%    80.500000
# 75%    89.750000
# max    92.000000

# %%
z=pd.read_csv('F20file3.csv')
z
# Out:
#   Unnamed: 0   name generations Country
# 0      first   F-22         5th     USA
# 1     second  SU-57         5th  Russia
# 2      third   J-20         5th   China
# 3     fourth   F-35         5th     USA

# %%
z['name']
# Out:
# 0     F-22
# 1    SU-57
# 2     J-20
# 3     F-35
# Name: name, dtype: str

# %%
z['name'][0]
# Out:
# 'F-22'

# %%
z.index=['first','second','third','fourth']
z
# Out:
#        Unnamed: 0   name generations Country
# first       first   F-22         5th     USA
# second     second  SU-57         5th  Russia
# third       third   J-20         5th   China
# fourth     fourth   F-35         5th     USA

# %%
#z.to_csv('F20file3.csv')

# %%
ser=pd.Series(np.random.rand(10))
ser
# Out:
# 0    0.622722
# 1    0.199052
# 2    0.256186
# 3    0.824833
# 4    0.174820
# 5    0.565593
# 6    0.974885
# 7    0.873063
# 8    0.668318
# 9    0.630536
# dtype: float64

# %%
type(ser)
# Out:
# pandas.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.397314  0.395114  0.059438  0.890089  0.421118
# 1  0.297441  0.475851  0.969424  0.224565  0.209864
# 2  0.138517  0.118858  0.285406  0.858676  0.528066
# 3  0.354476  0.956019  0.392527  0.347017  0.466866
# 4  0.671708  0.069636  0.936762  0.167340  0.878884

# %%
type(newdf)
# Out:
# pandas.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.501776    0.505082    0.466923    0.495171    0.531809
# std      0.280268    0.312803    0.282638    0.286338    0.305669
# min      0.002231    0.002412    0.002967    0.010566    0.003013
# 25%      0.262915    0.209948    0.221242    0.254612    0.256360
# 50%      0.514602    0.524307    0.463532    0.483870    0.563363
# 75%      0.743004    0.780334    0.722333    0.737822    0.805070
# max      0.999637    0.999675    0.996215    0.998312    0.999642

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][0]="groot"
# Out:
# C:\Users\anubh\AppData\Local\Temp\ipykernel_22724\728551213.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   newdf[0][0]="groot"
# ---------------------------------------------------------------------------
# LossySetitemError                         Traceback (most recent call last)
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\series.py:1090, in Series.__setitem__(self, key, value)
#    1089 try:
# -> 1090     self._set_with_engine(key, value)
#    1091 except KeyError:
#    1092     # We have a scalar (or for MultiIndex or object-dtype, scalar-like)
#    1093     #  key that is not present in self.index.
#    1094     # GH#12862 adding a new key to the Series
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\series.py:1143, in Series._set_with_engine(self, key, value)
#    1142 # this is equivalent to self._values[key] = value
# -> 1143 self._mgr.setitem_inplace(loc, value)
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\internals\managers.py:2228, in SingleBlockManager.setitem_inplace(self, indexer, value)
#    2225 if isinstance(arr, np.ndarray):
#    2226     # Note: checking for ndarray instead of np.dtype means we exclude
#    2227     #  dt64/td64, which do their own validation.
# -> 2228     value = np_can_hold_element(arr.dtype, value)
#    2230 if isinstance(value, np.ndarray) and value.ndim == 1 and len(value) == 1:
#    2231     # NumPy 1.25 deprecation: https://github.com/numpy/numpy/pull/10615
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\dtypes\cast.py:1792, in np_can_hold_element(dtype, element)
#    1790         return element
# -> 1792     raise LossySetitemError
#    1794 if dtype.kind == "c":
#
# LossySetitemError:
#
# During handling of the above exception, another exception occurred:
#
# LossySetitemError                         Traceback (most recent call last)
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\internals\blocks.py:1115, in Block.setitem(self, indexer, value)
#    1114 try:
# -> 1115     casted = np_can_hold_element(values.dtype, value)
#    1116 except LossySetitemError:
#    1117     # current dtype cannot store value, coerce to common dtype
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\dtypes\cast.py:1792, in np_can_hold_element(dtype, element)
#    1790         return element
# -> 1792     raise LossySetitemError
#    1794 if dtype.kind == "c":
#
# LossySetitemError:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 newdf[0][0]="groot"
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\series.py:1100, in Series.__setitem__(self, key, value)
#    1097 except (TypeError, ValueError, LossySetitemError):
#    1098     # The key was OK, but we cannot set the value losslessly
#    1099     indexer = self.index.get_loc(key)
# -> 1100     self._set_values(indexer, value)
#    1102 except InvalidIndexError as err:
#    1103     if isinstance(key, tuple) and not isinstance(self.index, MultiIndex):
#    1104         # cases with MultiIndex don't get here bc they raise KeyError
#    1105         # e.g. test_basic_getitem_setitem_corner
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\series.py:1168, in Series._set_values(self, key, value)
#    1165 if isinstance(key, (Index, Series)):
#    1166     key = key._values
# -> 1168 self._mgr = self._mgr.setitem(indexer=key, value=value)
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\internals\managers.py:607, in BaseBlockManager.setitem(self, indexer, value)
#     603     # No need to split if we either set all columns or on a single block
#     604     # manager
#     605     self = self.copy(deep=True)
# --> 607 return self.apply("setitem", indexer=indexer, value=value)
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\internals\blocks.py:1118, in Block.setitem(self, indexer, value)
#    1115     casted = np_can_hold_element(values.dtype, value)
#    1116 except LossySetitemError:
#    1117     # current dtype cannot store value, coerce to common dtype
# -> 1118     nb = self.coerce_to_target_dtype(value, raise_on_upcast=True)
#    1119     return nb.setitem(indexer, value)
#    1120 else:
#
# File c:\Users\anubh\.conda\envs\ml_env\Lib\site-packages\pandas\core\internals\blocks.py:468, in Block.coerce_to_target_dtype(self, other, raise_on_upcast)
#     465     raise_on_upcast = False
#     467 if raise_on_upcast:
# --> 468     raise TypeError(f"Invalid value '{other}' for dtype '{self.values.dtype}'")
#     469 if self.values.dtype == new_dtype:
#     470     raise AssertionError(
#     471         f"Did not expect new dtype {new_dtype} to equal self.dtype "
#     472         f"{self.values.dtype}. Please report a bug at "
#     473         "https://github.com/pandas-dev/pandas/issues."
#     474     )
#
# TypeError: Invalid value 'groot' for dtype 'float64'
