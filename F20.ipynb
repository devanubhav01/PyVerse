# %% [markdown]
# # PANDAS

# %%
import numpy as np 
import pandas as pd

# %%
dict1={
    "name":['Tom','Groot','Rocket','Thanos'],
    "marks":[92,72,64,89],
    "city":["New York","New Delhi","London","Berlin"]
}

# %%
df=pd.DataFrame(dict1)
df
# Out:
#      name  marks       city
# 0     Tom     92   New York
# 1   Groot     72  New Delhi
# 2  Rocket     64     London
# 3  Thanos     89     Berlin

# %%
df.to_csv('F20file1.csv')
